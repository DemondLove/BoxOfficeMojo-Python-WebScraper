# %%
# BoxOfficeMojo Python WebScraper Master Script

if __name__ == '__main__':
    import sys
    import os
    import inspect
    # from imp import reload
    import pandas as pd

    filename = inspect.getframeinfo(inspect.currentframe()).filename
    curpath = os.path.dirname(os.path.abspath(filename))
    sys.path.insert(0, curpath + '/utils')

    import utils

    HomeDirectory = 'https://www.boxofficemojo.com/yearly/'

    MasterURLs = utils.MasterURLsparser(HomeDirectory)

    df = pd.DataFrame()

    for url in MasterURLs:
        df = df.append(
            {
                'Title': utils.titleparser(url)
                , 'Distributor': utils.distributorparser(url)
                , 'Genre': utils.genreparser(url)
                , 'MPAA Rating': utils.mpaaratingparser(url)
                , 'Production Budget': utils.productionbudgetparser(url)
                , 'Release Date': utils.releasedateparser(url)
                , 'Runtime': utils.runtimeparser(url)
                , 'Domestic': utils.domesticparser(url)
                , 'Foreign': utils.foreignparser(url)
                , 'Worldwide': utils.worldwideparser(url)
                , 'Opening Weekend Gross': utils.openingweekendgrossparser(url)
                , 'Opening Weekend Theaters': utils.openingweekendtheatersparser(url)
                , 'Widest Theaters': utils.widestreleaseparser(url)
                # , 'Director': utils.directorparser(url)
                # , 'Writer': utils.writerparser(url)
                # , 'Actors': utils.actorparser(url)
                # , 'Producer': utils.producerparser(url)
                # , 'Composer': utils.composerparser(url)
                , 'Genres': utils.genresparser(url)
                , 'URL': str(url)
            }, ignore_index=True
        )
        
#     df.to_csv(curpath + '/data/BoxOfficeMojoDataset.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5d5bc6935fde> in <module>()
#      31                 , 'Runtime': utils.runtimeparser(url)
#      32                 , 'Domestic': utils.domesticparser(url)
# ---> 33                 , 'Foreign': utils.foreignparser(url)
#      34                 , 'Worldwide': utils.worldwideparser(url)
#      35                 , 'Opening Weekend Gross': utils.openingweekendgrossparser(url)
#
# ~/Documents/Projects/BoxOfficeMojo-Python-WebScraper/src/utils/utils.py in foreignparser(url)
#     514 def foreignparser(url):
#     515     try:
# --> 516         soup = downloadhtml(url)
#     517         if soup is None:
#     518             return 'NULL'
#
# ~/Documents/Projects/BoxOfficeMojo-Python-WebScraper/src/utils/utils.py in downloadhtml(url)
#     129 def downloadhtml(url):
#     130     try:
# --> 131         page = requests.get(url)
#     132         if 'Sorry, we\'re not able to process your request.' in BeautifulSoup(page.content, 'lxml').find('div', id='main').find('p'):
#     133             return None
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     443                     decode_content=False,
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#     447
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 2.6 and older, Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     283     def recv_into(self, *args, **kwargs):
#     284         try:
# --> 285             return self.connection.recv_into(*args, **kwargs)
#     286         except OpenSSL.SSL.SysCallError as e:
#     287             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
df
# Out:
#                     Distributor      Domestic       Foreign  \
# 0                   Buena Vista  $400,031,743  $690,079,633
# 1                     Universal  $159,087,575  $355,600,000
# 2                     Universal  $111,035,005  $135,918,064
# 3                  Warner Bros.  $105,574,878   $83,600,000
# 4                           Fox   $85,582,008  $318,331,074
# 5               Sony / Columbia   $57,000,756   $97,374,314
# 6                     Paramount   $49,596,308   $46,100,000
# 7                     Lionsgate   $45,040,875   $25,704,807
# 8               Sony / Columbia   $42,004,346   $33,459,671
# 9              FUNimation Films   $30,712,119   $80,137,244
# 10                    Universal   $28,051,045   $36,192,022
# 11                          MGM   $22,854,386   $15,600,000
# 12                    Pure Flix   $17,207,329          None
# 13              Sony / Columbia   $15,006,824      $227,877
# 14                          Fox   $14,789,258    $5,825,303
# 15               Focus Features   $10,519,425    $3,000,000
# 16            STX Entertainment    $9,585,764          None
# 17              Bleecker Street    $8,938,874          None
# 18                         Neon    $8,475,123          None
# 19               Focus Features    $5,958,315    $2,409,042
# 20   Viva Pictures Distribution    $5,566,534           n/a
# 21                  PackYourBag    $4,186,168           n/a
# 22               Focus Features    $4,017,695          None
# 23                       Fathom    $3,509,917           n/a
# 24                  Buena Vista    $3,234,350          None
# 25              Bleecker Street    $2,374,719          None
# 26                          FIP    $2,167,632   $22,863,635
# 27        Reliance Big Pictures    $1,861,000          None
# 28             CJ Entertainment    $1,565,885  $118,366,848
# 29                    Lionsgate    $1,508,593          None
# ..                          ...           ...           ...
# 107             Sony / Columbia  $190,241,310  $184,858,940
# 108                Warner Bros.  $174,532,921   $64,000,000
# 109             Sony / Columbia  $167,510,016  $361,073,758
# 110                   Universal  $159,342,015   $94,943,694
# 111                Warner Bros.  $140,218,711  $157,500,000
# 112                   Paramount  $127,195,589  $340,513,536
# 113     Warner Bros. (New Line)  $117,450,119  $248,100,000
# 114             Sony / Columbia  $115,253,424  $236,013,009
# 115             Sony / Columbia  $102,084,362   $88,315,795
# 116                 Buena Vista  $100,478,608   $32,197,256
# 117                 Buena Vista   $99,215,042   $98,529,335
# 118        Roadside Attractions   $83,482,352          None
# 119                   Universal   $77,339,130   $25,755,573
# 120     Warner Bros. (New Line)   $69,179,066   $48,500,000
# 121                   Universal   $68,549,695   $62,907,452
# 122                   Universal   $67,745,330  $100,140,258
# 123                   Universal   $60,311,495   $33,733,798
# 124                Warner Bros.   $58,250,803  $216,400,000
# 125                 Buena Vista   $54,858,851  $119,102,218
# 126                   Lionsgate   $53,548,586   $44,080,131
# 127                         Fox   $51,024,708  $109,517,426
# 128             Sony / Columbia   $50,072,235   $25,764,448
# 129           STX Entertainment   $48,795,601   $45,743,825
# 130                         Fox   $46,874,505  $104,698,129
# 131             Sony / Columbia   $46,700,633   $46,619,747
# 132           STX Entertainment   $44,947,622   $35,562,000
# 133                         A24   $44,069,456   $35,267,365
# 134                   Paramount   $43,242,871   $47,103,000
# 135                         Fox   $42,402,632   $33,582,068
# 136                Warner Bros.   $40,891,591  $186,440,347
#
#                   Genre                                             Genres  \
# 0    Action / Adventure  ['Action Heroine', 'Sci-Fi - Alien Invasion', ...
# 1             Animation                  ['Dragon - Focal Point of Movie']
# 2              Thriller                                                 []
# 3             Animation                                                 []
# 4    Action / Adventure                                                 []
# 5              Thriller                            ['Series: Escape Room']
# 6                Horror                                                 []
# 7               Romance                                                 []
# 8      Family Adventure                                                 []
# 9             Animation                              ['Animation - Anime']
# 10               Horror                                                 []
# 11       Comedy / Drama                                  ['Sundance 2019']
# 12                Drama                                                 []
# 13      Action Thriller                                                 []
# 14                Drama                                                 []
# 15     Drama / Thriller                                                 []
# 16                Drama                                                 []
# 17                Drama                                                 []
# 18          Documentary                                  ['Sundance 2019']
# 19               Sci-Fi                                                 []
# 20                Drama                                                 []
# 21         Action Drama                                                 []
# 22                Drama                                  ['Sundance 2019']
# 23          Documentary                                                 []
# 24          Documentary                                                 []
# 25     Drama / Thriller                                                 []
# 26        Action Comedy                                                 []
# 27                Crime                                                 []
# 28               Comedy                                                 []
# 29         Action Drama                                                 []
# ..                  ...                                                ...
# 107           Animation    ['Nominated for One Oscar, Including One Win.']
# 108     Romantic Comedy                                ['Romantic Comedy']
# 109           Animation                                        ['Vampire']
# 110              Horror           ['Horror - R-Rated', 'Horror - Slasher']
# 111  Action / Adventure                                  ['Heist / Caper']
# 112       Sci-Fi Action                                 ['Toy Adaptation']
# 113              Horror  ['Horror - Period', 'Horror - R-Rated', 'Horro...
# 114              Family          ['Family - Talking Animal (Live action)']
# 115            Thriller                                                 []
# 116             Fantasy                                                 []
# 117             Fantasy                       ['Nominated for One Oscar.']
# 118              Family                    ['Biopic - Music', 'Christian']
# 119              Comedy                                                 []
# 120       Action Comedy                                                 []
# 121             Fantasy                                                 []
# 122              Horror                                                 []
# 123              Comedy                                                 []
# 124  Action / Adventure                          ['Video Game Adaptation']
# 125           Adventure                                    ['Mouse / Rat']
# 126            Thriller                                                 []
# 127       Sci-Fi Action                                                 []
# 128  Action / Adventure                                ['Series: Sicario']
# 129              Comedy                                                 []
# 130            Thriller                                                 []
# 131              Comedy                                                 []
# 132     Action Thriller                                                 []
# 133              Horror                                  ['Sundance 2018']
# 134           Animation                                                 []
# 135      Crime Thriller                                                 []
# 136    Family Adventure                                                 []
#
#        MPAA Rating Opening Weekend Gross Opening Weekend Theaters  \
# 0            PG-13          $153,433,423           4,310 theaters
# 1               PG           $55,022,245           4,259 theaters
# 2            PG-13           $40,328,920           3,841 theaters
# 3               PG           $34,115,335           4,303 theaters
# 4            PG-13           $28,525,613           3,790 theaters
# 5            PG-13           $18,238,172           2,717 theaters
# 6                R           $24,502,775           3,585 theaters
# 7            PG-13           $13,190,286           2,803 theaters
# 8               PG           $11,251,263           3,090 theaters
# 9               PG            $9,816,197           1,238 theaters
# 10           PG-13            $9,497,665           3,207 theaters
# 11           PG-13                  None                     None
# 12               R            $6,382,298           1,059 theaters
# 13           PG-13            $6,864,744           2,203 theaters
# 14              PG           $11,282,333           2,824 theaters
# 15               R            $4,481,910           2,411 theaters
# 16           PG-13            $4,446,190           1,705 theaters
# 17               R                  None                     None
# 18               G            $1,607,040             120 theaters
# 19   Not Yet Rated            $3,131,525           2,548 theaters
# 20         Unrated            $2,045,068             258 theaters
# 21         Unrated              $631,146             101 theaters
# 22               R               $71,657               4 theaters
# 23         Unrated            $2,860,016             997 theaters
# 24               G            $2,282,593           1,815 theaters
# 25           PG-13               $50,878               4 theaters
# 26         Unrated              $989,387             202 theaters
# 27         Unrated              $596,446              50 theaters
# 28         Unrated               $42,587               2 theaters
# 29               R              $514,286             268 theaters
# ..             ...                   ...                      ...
# 107             PG           $35,363,376           3,813 theaters
# 108          PG-13           $26,510,140           3,384 theaters
# 109             PG           $44,076,225           4,267 theaters
# 110              R           $76,221,545           3,928 theaters
# 111          PG-13           $41,607,378           4,145 theaters
# 112          PG-13           $21,654,047           3,550 theaters
# 113              R           $53,807,379           3,876 theaters
# 114             PG           $25,010,928           3,725 theaters
# 115              R           $36,011,640           3,388 theaters
# 116             PG           $33,123,609           3,980 theaters
# 117             PG           $24,585,139           3,602 theaters
# 118             PG           $17,108,914           1,629 theaters
# 119          PG-13           $27,257,615           3,010 theaters
# 120              R           $17,005,332           3,488 theaters
# 121             PG           $26,608,020           3,592 theaters
# 122          PG-13           $29,581,355           3,116 theaters
# 123              R           $20,556,350           3,379 theaters
# 124          PG-13           $23,633,317           3,854 theaters
# 125             PG           $20,352,491           3,766 theaters
# 126              R           $16,011,689           3,102 theaters
# 127              R           $24,632,284           4,037 theaters
# 128              R           $19,007,566           3,055 theaters
# 129          PG-13           $16,030,218           3,440 theaters
# 130              R           $16,853,422           3,056 theaters
# 131             PG           $15,802,225           3,521 theaters
# 132              R           $15,206,108           2,432 theaters
# 133              R           $13,575,172           2,964 theaters
# 134             PG           $10,604,774           3,662 theaters
# 135              R           $12,361,307           2,803 theaters
# 136             PG           $11,001,961           3,702 theaters
#
#     Production Budget        Release Date         Runtime  \
# 0                 N/A       March 8, 2019   2 hrs. 8 min.
# 1        $129 million   February 22, 2019  1 hrs. 44 min.
# 2         $20 million    January 18, 2019   2 hrs. 9 min.
# 3                 N/A    February 8, 2019  1 hrs. 46 min.
# 4        $170 million   February 14, 2019   2 hrs. 2 min.
# 5          $9 million     January 4, 2019  1 hrs. 40 min.
# 6         $21 million       April 5, 2019  1 hrs. 41 min.
# 7                 N/A      March 15, 2019  1 hrs. 56 min.
# 8         $18 million    January 11, 2019  1 hrs. 36 min.
# 9                 N/A    January 16, 2019  1 hrs. 40 min.
# 10         $9 million   February 13, 2019  1 hrs. 40 min.
# 11                N/A   February 14, 2019  1 hrs. 47 min.
# 12         $6 million      March 29, 2019  1 hrs. 50 min.
# 13        $15 million    February 1, 2019  1 hrs. 44 min.
# 14                N/A      April 17, 2019  1 hrs. 56 min.
# 15                N/A       March 1, 2019  1 hrs. 38 min.
# 16        $10 million       April 5, 2019  2 hrs. 13 min.
# 17                N/A      March 22, 2019   2 hrs. 5 min.
# 18                N/A       March 1, 2019  1 hrs. 33 min.
# 19                N/A      March 15, 2019  1 hrs. 49 min.
# 20                N/A   February 14, 2019  2 hrs. 33 min.
# 21                N/A    January 11, 2019  2 hrs. 18 min.
# 22                N/A      March 15, 2019  1 hrs. 36 min.
# 111  https://www.boxofficemojo.com/movies/?id=wbeve...  4,145 theaters
# 112  https://www.boxofficemojo.com/movies/?id=trans...  3,597 theaters
# 113  https://www.boxofficemojo.com/movies/?id=thenu...  3,876 theaters
# 114  https://www.boxofficemojo.com/movies/?id=peter...  3,725 theaters
# 115  https://www.boxofficemojo.com/movies/?id=theeq...  3,388 theaters
# 116  https://www.boxofficemojo.com/movies/?id=ladis...  3,980 theaters
# 117  https://www.boxofficemojo.com/movies/?id=disne...  3,602 theaters
# 118  https://www.boxofficemojo.com/movies/?id=icano...  2,894 theaters
# 119  https://www.boxofficemojo.com/movies/?id=night...  3,019 theaters
# 120  https://www.boxofficemojo.com/movies/?id=gamen...  3,502 theaters
# 121  https://www.boxofficemojo.com/movies/?id=theho...  3,592 theaters
# 122  https://www.boxofficemojo.com/movies/?id=insid...  3,150 theaters
# 123  https://www.boxofficemojo.com/movies/?id=unirr...  3,418 theaters
# 124  https://www.boxofficemojo.com/movies/?id=dcfil...  3,854 theaters
# 125  https://www.boxofficemojo.com/movies/?id=nutcr...  3,766 theaters
# 126  https://www.boxofficemojo.com/movies/?id=asimp...  3,102 theaters
# 127  https://www.boxofficemojo.com/movies/?id=thepr...  4,070 theaters
# 128  https://www.boxofficemojo.com/movies/?id=sicar...  3,055 theaters
# 129  https://www.boxofficemojo.com/movies/?id=ifeel...  3,440 theaters
# 130  https://www.boxofficemojo.com/movies/?id=redsp...  3,064 theaters
# 131  https://www.boxofficemojo.com/movies/?id=goose...  3,723 theaters
# 132  https://www.boxofficemojo.com/movies/?id=denof...  2,432 theaters
# 133  https://www.boxofficemojo.com/movies/?id=a24ho...  2,998 theaters
# 134  https://www.boxofficemojo.com/movies/?id=sherl...  3,662 theaters
# 135  https://www.boxofficemojo.com/movies/?id=widow...  2,803 theaters
# 136  https://www.boxofficemojo.com/movies/?id=paddi...  3,702 theaters
#
#           Worldwide
# 0    $1,090,111,376
# 1      $514,687,575
# 2      $246,953,069
# 3      $189,174,878
# 4      $403,913,082
# 5      $154,375,070
# 6       $95,696,308
# 7       $70,745,682
# 8       $75,464,017
# 9      $110,849,363
# 10      $64,243,067
# 11      $38,454,386
# 12             None
# 13      $15,234,701
# 14      $20,614,561
# 15      $13,519,425
# 16             None
# 17             None
# 18             None
# 19       $8,367,357
# 20       $5,566,534
# 21       $4,186,168
# 22             None
# 23       $3,509,917
# 24             None
# 25             None
# 26      $25,031,267
# 27             None
# 28     $119,932,733
# 29             None
# ..              ...
# 107    $375,100,250
# 108    $238,532,921
# 109    $528,583,774
# 110    $254,285,709
# 111    $297,718,711
# 112    $467,709,125
# 113    $365,550,119
# 114    $351,266,433
# 115    $190,400,157
# 116    $132,675,864
# 117    $197,744,377
# 118            None
# 119    $103,094,703
# 120    $117,679,066
# 121    $131,457,147
# 122    $167,885,588
# 123     $94,045,293
# 124    $274,650,803
# 125    $173,961,069
# 126     $97,628,717
# 127    $160,542,134
# 128     $75,836,683
# 129     $94,539,426
# 130    $151,572,634
# 131     $93,320,380
# 132     $80,509,622
# 133     $79,336,821
# 134     $90,345,871
# 135     $75,984,700
# 136    $227,331,938
#
# [137 rows x 15 columns]
